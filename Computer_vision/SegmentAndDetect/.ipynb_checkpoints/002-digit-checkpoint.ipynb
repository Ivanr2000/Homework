# %% [markdown]
# ## Digit Recognizer
# https://www.kaggle.com/c/digit-recognizer

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.5.3

# %% [markdown]
# ## Загружаем исходные данные

# %%
train = np.loadtxt('./data/digit/train.csv', delimiter=',', skiprows=1)
test = np.loadtxt('./data/digit/test.csv', delimiter=',', skiprows=1)

# %%
# сохраняем разметку в отдельную переменную
train_label = train[:, 0]
# приводим размерность к удобному для обаботки виду
train_img = np.resize(train[:, 1:], (train.shape[0], 28, 28))
test_img = np.resize(test, (test.shape[0], 28, 28))

# %%
train_img.shape
# Out:
# (42000, 28, 28)

# %% [markdown]
# ## Визуализируем исходные данные

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_img[0:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);

# %% [markdown]
# ## Выравниваем цифры

# %%
SZ=28
affine_flags = cv2.WARP_INVERSE_MAP|cv2.INTER_LINEAR
def deskew(img):
    m = cv2.moments(img)
    if abs(m['mu02']) < 1e-2:
        return img.copy()
    skew = m['mu11']/m['mu02']
    M = np.float32([[1, skew, -0.5*SZ*skew], [0, 1, 0]])
    img = cv2.warpAffine(img,M,(SZ, SZ),flags=affine_flags)
    return img

# %%
for i, img in enumerate(train_img, 1):
    train_img[i - 1]=deskew(img)

# %%
for i, img in enumerate(test_img, 1):
    test_img[i - 1]=deskew(img)

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_img[0:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);

# %% [markdown]
# ## Вычисляем X и Y составляющие градиента с помощью оператора Собеля

# %%
train_sobel_x = np.zeros_like(train_img)
train_sobel_y = np.zeros_like(train_img)
for i in range(len(train_img)):
    train_sobel_x[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    train_sobel_y[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %%
test_sobel_x = np.zeros_like(test_img)
test_sobel_y = np.zeros_like(test_img)
for i in range(len(test_img)):
    test_sobel_x[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    test_sobel_y[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %% [markdown]
# ## Вычисляем угол и длину вектора градиента

# %%
train_g, train_theta = cv2.cartToPolar(train_sobel_x, train_sobel_y)

# %%
test_g, test_theta = cv2.cartToPolar(test_sobel_x, test_sobel_y)

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_g[:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);
    subplot = fig.add_subplot(3, 7, i)
    plt.hist(train_theta[i - 1].flatten(),
             bins=16, weights=train_g[i - 1].flatten())

# %% [markdown]
# ## Вычисляем гистограммы градиентов

# %%
# Гистограммы вычисляются с учетом длины вектора градиента
train_hist = np.zeros((len(train_img), 16))
for i in range(len(train_img)):
    hist, borders = np.histogram(train_theta[i],
                                 bins=16,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i])
    train_hist[i] = hist

# %%
test_hist = np.zeros((len(test_img), 16))
for i in range(len(test_img)):
    hist, borders = np.histogram(test_theta[i],
                                 bins=16,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i])
    test_hist[i] = hist

# %% [markdown]
# ## Нормируем вектор гистограммы

# %%
# По умолчанию используется L2 норма
train_hist = train_hist / np.linalg.norm(train_hist, axis=1)[:, None]

# %%
test_hist = test_hist / np.linalg.norm(test_hist, axis=1)[:, None]

# %% [markdown]
# ## Разбиваем выборку на обучение и валидацию

# %%
from sklearn.model_selection import train_test_split
y_train, y_val, x_train, x_val = train_test_split(
    train_label, train_hist, test_size=0.2,
    random_state=42)

# %%
from sklearn.svm import LinearSVC as SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# LinearSVC()

# %%
y_res_val = svc.predict(x_val)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy: %s' % accuracy_score(y_val, y_res_val))
# Out:
# Accuracy: 0.6544047619047619

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, y_res_val))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.60      0.57       816
#          1.0       0.92      0.98      0.95       909
#          2.0       0.52      0.15      0.23       846
#          3.0       0.62      0.79      0.70       937
#          4.0       0.69      0.55      0.61       839
#          5.0       0.59      0.76      0.67       702
#          6.0       0.58      0.68      0.63       785
#          7.0       0.75      0.79      0.77       893
#          8.0       0.55      0.53      0.54       835
#          9.0       0.66      0.69      0.68       838
#
#     accuracy                           0.65      8400
#    macro avg       0.64      0.65      0.63      8400
# weighted avg       0.65      0.65      0.64      8400

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_val, y_res_val))
# Out:
# [[488  13  19  27  20  36  28   2 171  12]
#  [  0 887   1   1  13   0   0   3   0   4]
#  [100   1 126 219  17 182  74  37  72  18]
#  [ 23   0  27 741   3  66  18   2  47  10]
#  [ 61  48  10   5 462   2  80  71   5  95]
#  [  8   1  21  85   2 534  12   6  30   3]
#  [ 35   1  14  21  58  15 536  31  29  45]
#  [ 12   4  12   9  32   7  45 703   1  68]
#  [161   5  10  64   4  58  47   4 441  41]
#  [ 16   2   3  19  55   3  77  73  11 579]]

# %%
y_res_test = svc.predict(test_hist)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy: %s' % accuracy_score(test[:, 0], y_res_test))
# Out:
# Accuracy: 0.10842857142857143

# %%
y_res_test
# Out:
# array([5., 5., 6., ..., 3., 9., 5.])

# %% [markdown]
# ## Готовим файл для отправки

# %%
with open('submit.csv', 'w') as dst:
    dst.write('ImageId,Label\n')
    for i, p in enumerate(y_res_test, 1):
        dst.write('%s,%d\n' % (i, p))

# %%
# !head submit.csv
# Out:
# "head" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# Your submission scored 0.64989
