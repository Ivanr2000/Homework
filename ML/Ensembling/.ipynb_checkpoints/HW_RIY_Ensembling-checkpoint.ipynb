# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from jupyterthemes import jtplot
from sklearn.metrics import auc, roc_curve, roc_auc_score
# %matplotlib inline
jtplot.style()
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %%
train_data = pd.read_csv('train.csv', index_col='Id')
test_data = pd.read_csv('test.csv', index_col='Id')
y_test = pd.read_csv('sample_submission.csv', index_col='Id')

# %%
train_data.fillna(-999, inplace=True)
train_data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  -999      Reg
# 2           20       RL         80.0     9600   Pave  -999      Reg
# 3           60       RL         68.0    11250   Pave  -999      IR1
# 4           70       RL         60.0     9550   Pave  -999      IR1
# 5           60       RL         84.0    14260   Pave  -999      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0   -999  -999        -999
# 2          Lvl    AllPub       FR2  ...        0   -999  -999        -999
# 3          Lvl    AllPub    Inside  ...        0   -999  -999        -999
# 4          Lvl    AllPub    Corner  ...        0   -999  -999        -999
# 5          Lvl    AllPub       FR2  ...        0   -999  -999        -999
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
test_data.fillna(-999, inplace=True)
test_data.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave  -999      Reg
# 1462          20       RL         81.0    14267   Pave  -999      IR1
# 1463          60       RL         74.0    13830   Pave  -999      IR1
# 1464          60       RL         78.0     9978   Pave  -999      IR1
# 1465         120       RL         43.0     5005   Pave  -999      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0   -999  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0   -999   -999
# 1463         Lvl    AllPub    Inside  ...           0        0   -999  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0   -999   -999
# 1465         HLS    AllPub    Inside  ...         144        0   -999   -999
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461        -999       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463        -999       0       3    2010        WD         Normal
# 1464        -999       0       6    2010        WD         Normal
# 1465        -999       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %%
#Находим категориальные признаки
cat_feat = list(train_data.dtypes[train_data.dtypes == object].index)

#отфильтруем непрерывные признаки
num_feat = [f for f in train_data if f not in (cat_feat + ['ID', 'SalePrice'])]

# Смотрим сколько у нас значений по каждому категориальному признаку
cat_nunique = train_data[cat_feat].nunique()

#Чтобы в разы не увеличивать число признаков при построении dummy,
#будем использовать категориальные признаки с < 30 уникальных значений
cat_feat = list(cat_nunique[cat_nunique < 30].index)

# %%
# Создаем дамми-переменные для категорий
dummy_train = pd.get_dummies(train_data[cat_feat], columns=cat_feat)
dummy_test = pd.get_dummies(test_data[cat_feat], columns=cat_feat)

dummy_cols = list(set(dummy_train) & set(dummy_test))

dummy_train = dummy_train[dummy_cols]
dummy_test = dummy_test[dummy_cols]

# %%
# Заменяем пропуски на специальное значение -999, чтобы деревья могли их отличить
X_train = pd.concat([train_data[num_feat],
                     dummy_train], axis=1)

X_test = pd.concat([test_data[num_feat],
                     dummy_test], axis=1)

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  MiscFeature_Othr  \
# Id                                                      ...
# 1461          1961         0.0       468.0       144.0  ...                 0
# 1462          1958       108.0       923.0         0.0  ...                 0
# 1463          1998         0.0       791.0         0.0  ...                 0
# 1464          1998        20.0       602.0         0.0  ...                 0
# 1465          1992         0.0       263.0         0.0  ...                 0
# ...            ...         ...         ...         ...  ...               ...
# 2915          1970         0.0         0.0         0.0  ...                 0
# 2916          1970         0.0       252.0         0.0  ...                 0
# 2917          1996         0.0      1224.0         0.0  ...                 0
# 2918          1992         0.0       337.0         0.0  ...                 0
# 2919          1994        94.0       758.0         0.0  ...                 0
#
#       Neighborhood_NPkVill  Street_Grvl  Condition1_RRAn  PoolQC_-999  \
# Id
# 1461                     0            0                0            1
# 1462                     0            0                0            1
# 1463                     0            0                0            1
# 1464                     0            0                0            1
# 1465                     0            0                0            1
# ...                    ...          ...              ...          ...
# 2915                     0            0                0            1
# 2916                     0            0                0            1
# 2917                     0            0                0            1
# 2918                     0            0                0            1
# 2919                     0            0                0            1
#
#       FireplaceQu_TA  GarageType_BuiltIn  Electrical_FuseF  \
# Id
# 1461               0                   0                 0
# 1462               0                   0                 0
# 1463               1                   0                 0
# 1464               0                   0                 0
# 1465               0                   0                 0
# ...              ...                 ...               ...
# 2915               0                   0                 0
# 2916               0                   0                 0
# 2917               1                   0                 0
# 2918               0                   0                 0
# 2919               1                   0                 0
#
#       SaleCondition_Family  Heating_GasW
# Id
# 1461                     0             0
# 1462                     0             0
# 1463                     0             0
# 1464                     0             0
# 1465                     0             0
# ...                    ...           ...
# 2915                     0             0
# 2916                     0             0
# 2917                     0             0
# 2918                     0             0
# 2919                     0             0
#
# [1459 rows x 285 columns]

# %%
y_train = train_data['SalePrice'] #создаем целевую переменную

# %%
y_train
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y_test
# Out:
#           SalePrice
# Id
# 1461  169277.052498
# 1462  187758.393989
# 1463  183583.683570
# 1464  179317.477511
# 1465  150730.079977
# ...             ...
# 2915  167081.220949
# 2916  164788.778231
# 2917  219222.423400
# 2918  184924.279659
# 2919  187741.866657
#
# [1459 rows x 1 columns]

# %% [markdown]
# Случайный лес Регрессор

# %%
lr_rf = RandomForestRegressor(n_estimators=10, max_depth=5, min_samples_leaf=20, max_features=0.5, n_jobs=-1) #создаем объект случайного леса регрессора
lr_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, max_features=0.5, min_samples_leaf=20,
#                       n_estimators=10, n_jobs=-1)

# %%
y_pred_train_rf = lr_rf.predict(X_train) #делаем предсказание на тренировочной выборке
y_pred_test_rf = lr_rf.predict(X_test) #делаем предсказание на тестоврй выборке

# %%
lr_rf.score(X_train, y_train)
# Out:
# 0.8362712476477728

# %%
lr_rf.score(X_test, y_test)
# Out:
# -14.03931799163557

# %%
#Определим важность признаков
imp = pd.Series(lr_rf.feature_importances_)
imp.sort_values(ascending=False)
# Out:
# 3      0.400121
# 25     0.187816
# 15     0.150087
# 18     0.054513
# 11     0.045213
#          ...
# 180    0.000000
# 179    0.000000
# 178    0.000000
# 177    0.000000
# 142    0.000000
# Length: 285, dtype: float64

# %% [markdown]
# Наиболее важным признаком для модели является 3-ий, площадь лота

# %% [markdown]
# По логика указанного датасета - признак для предсказания - это цена. Ничего другого в задании не указано. Так как цена не является категориальным признаком, то метрики входящие в "ROC" не применимы.

# %% [markdown]
# Стэккинг

# %%
train_median = train_data[num_feat].median()

X_train = pd.concat([train_data[num_feat].fillna(train_median),
                     train_data[num_feat + cat_feat].isnull().astype(np.int8).add_suffix('_NaN'),
                     dummy_train], axis=1)

X_test = pd.concat([test_data[num_feat].fillna(train_median),
                     test_data[num_feat + cat_feat].isnull().astype(np.int8).add_suffix('_NaN'),
                     dummy_test], axis=1)

scaler = StandardScaler()
scaler.fit(X_train[num_feat])

X_train[num_feat] = scaler.transform(X_train[num_feat])
X_test[num_feat] = scaler.transform(X_test[num_feat])

# %%
regressor = StackingRegressor(
    [
        ('li', LinearRegression()),
        ('dt', DecisionTreeRegressor()),
        ('rf', RandomForestRegressor())
    ],
LinearRegression())

# %%
regressor.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('li', LinearRegression()),
#                               ('dt', DecisionTreeRegressor()),
#                               ('rf', RandomForestRegressor())],
#                   final_estimator=LinearRegression())

# %%
regressor.named_estimators_
# Out:
# {'li': LinearRegression(),
#  'dt': DecisionTreeRegressor(),
#  'rf': RandomForestRegressor()}

# %%
y_pred_li = regressor.named_estimators_['li'].predict(X_test)
y_pred_li
# Out:
# array([109156., 124172., 180324., ..., 174140., 113544., 224508.])

# %%
regressor.named_estimators_['li'].score(X_test, y_test)
# Out:
# -1.0858191146722656e+21

# %%
y_pred_dt = regressor.named_estimators_['dt'].predict(X_test)
y_pred_dt
# Out:
# array([122000., 145000., 192000., ..., 142000., 108000., 222000.])

# %%
regressor.named_estimators_['dt'].score(X_test, y_test)
# Out:
# -20.04156861906413

# %%
y_pred_rf = regressor.named_estimators_['rf'].predict(X_test)
y_pred_rf
# Out:
# array([126771.08, 155667.82, 185007.5 , ..., 153995.73, 116312.1 ,
#        227510.74])

# %%
regressor.named_estimators_['rf'].score(X_test, y_test)
# Out:
# -17.233044425312308

# %%
y_pred_st = regressor.predict(X_test)
y_pred_st
# Out:
# array([124674.43367934, 155153.51514737, 184912.07245802, ...,
#        153473.69746165, 113927.78427018, 229935.08726092])

# %%
regressor.score(X_test, y_test)
# Out:
# -18.958772667585205

# %%
regressor.final_estimator_
# Out:
# LinearRegression()

# %%
pd.Series(regressor.final_estimator_.coef_.flatten(), index=regressor.named_estimators_.keys()).plot(kind='barh')
# Out:
# <AxesSubplot:>
