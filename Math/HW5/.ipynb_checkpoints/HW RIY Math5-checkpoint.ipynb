# %%
import numpy as np
from scipy.optimize import approx_fprime
import math

# %% [markdown]
# Уровень 0:
#
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$, а для этой функции также градиент в точке $(1,2)$

# %%
from sympy import * 
x, y = symbols('x y')

# %%
exp = (2*x**2*y**3) + 1/x + y**2*x + 7  
    
print("Для выражения 𝑓(𝑥,𝑦)=2𝑥2𝑦3+1/𝑥+𝑦2𝑥+7 частная производная по х: ", diff(exp, x), ", частная производная по y: ", diff(exp, y))
# Out:
# Для выражения 𝑓(𝑥,𝑦)=2𝑥2𝑦3+1/𝑥+𝑦2𝑥+7 частная производная по х:  4*x*y**3 + y**2 - 1/x**2 , частная производная по y:  6*x**2*y**2 + 2*x*y

# %%
def func (x):
    return (2*x[0]**2*x[1]**3) + 1/x[0] + x[1]**2*x[0] + 7

# %%
x = np.array([1, 2])
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, func, [eps, eps])
# Out:
# array([35.00000024, 28.00000024])

# %% [markdown]
# #
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %%
exp = x**2*y - sin(x*y) + cos(x**2) + 6*y  
    
print("Для выражения 𝑓(𝑥,𝑦)=𝑥2𝑦−𝑠𝑖𝑛(𝑥𝑦)+𝑐𝑜𝑠(𝑥2)+6𝑦 частная производная по х: ", diff(exp, x), ", частная производная по y: ", diff(exp, y))
# Out:
# Для выражения 𝑓(𝑥,𝑦)=𝑥2𝑦−𝑠𝑖𝑛(𝑥𝑦)+𝑐𝑜𝑠(𝑥2)+6𝑦 частная производная по х:  2*x*y - 2*x*sin(x**2) - y*cos(x*y) , частная производная по y:  x**2 - x*cos(x*y) + 6

# %% [markdown]
# #
#
# Уровень 1:
#
# Градиентный спуск своими руками:

# %%
from scipy.optimize import minimize

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
learning_rate = 0.1

# %%
for i in range(100):
    # Calculate gradient
    grad = approx_fprime(x, f, [eps, eps])
    
    # Update x with gradient
    x = minimize(f, grad, method='nelder-mead', options = {'xtol':1e-8, 'disp':True}).x
    print (x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [ 3.87586341e-09 -3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 2.26528880e-08 -2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 6.02069372e-08 -6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [ 1.35315036e-07 -1.35887243e-07]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 33
# [-3.87586341e-09  3.94738927e-09]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-2.26528880e-08  2.27959397e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-6.02069372e-08  6.04930407e-08]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
# [-1.35315036e-07  1.35887243e-07]

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [-1.35315036e-07  1.35887243e-07]
# Значение функции в минимуме:  3.677550154500694e-14
