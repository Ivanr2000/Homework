# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
rv = sts.norm (2.0, 0.5)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n1 = 2
n2 = 10
n3 = 15
n4 = 20
n5 = 30
n6 = 50
n7 = 100
n8 = 500
n9 = 900

samples_count = 1000
# Массивы для сохранения средних по выборкам
a1 = np.array([])
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])
a5 = np.array([])
a6 = np.array([])
a7 = np.array([])
a8 = np.array([])
a9 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    sample5 = rv.rvs(size=n5)
    sample6 = rv.rvs(size=n6)
    sample7 = rv.rvs(size=n7)
    sample8 = rv.rvs(size=n8)
    sample9 = rv.rvs(size=n9)

    # Считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())
    a5 = np.append(a5, sample5.mean())
    a6 = np.append(a6, sample6.mean())
    a7 = np.append(a7, sample7.mean())
    a8 = np.append(a8, sample8.mean())
    a9 = np.append(a9, sample9.mean())

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'

plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'

plt.hist(a2, density=True, label=label_2)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_3 = 'sample of ' + str(n3) + ' histogram'

plt.hist(a3, density=True, label=label_3)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_4 = 'sample of ' + str(n4) + ' histogram'

plt.hist(a4, density=True, label=label_4)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_5 = 'sample of ' + str(n5) + ' histogram'

plt.hist(a5, density=True, label=label_5)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_6 = 'sample of ' + str(n6) + ' histogram'

plt.hist(a6, density=True, label=label_6)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_7 = 'sample of ' + str(n7) + ' histogram'

plt.hist(a7, density=True, label=label_7)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_8 = 'sample of ' + str(n8) + ' histogram'

plt.hist(a8, density=True, label=label_8)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_9 = 'sample of ' + str(n9) + ' histogram'

plt.hist(a9, density=True, label=label_9)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')
